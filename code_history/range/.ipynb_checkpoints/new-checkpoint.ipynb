# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('accepted.gz', sep = " ", header= None)
xdata = df.iloc[:, 0]
ydata = df.iloc[:, 1]
zdata = df.iloc[:, 2]
tdata = df.iloc[:, 3]

# %%
fig = plt.figure(figsize=plt.figaspect(0.5))

ax = fig.add_subplot(2, 2, 1, projection='3d')
#ax.set_title('1_2_3')
ax.set_xlabel('log_10(pop_rad_yield_0_)')
ax.set_ylabel('log_10(pop_rad_yield_1_)')
ax.set_zlabel('log_10(pop_rad_yield_2_)')
ax.scatter3D(xdata, ydata, zdata, marker= '.')


ax = fig.add_subplot(2, 2, 2, projection='3d')
#ax.set_title('1_2_4')
ax.set_xlabel('log_10(pop_rad_yield_0_)')
ax.set_ylabel('log_10(pop_rad_yield_1_)')
ax.set_zlabel('clumping factor')
ax.scatter3D(xdata, ydata, tdata, marker= '.')

ax = fig.add_subplot(2, 2, 3, projection='3d')
#ax.set_title('2_3_4')
ax.set_xlabel('log_10(pop_rad_yield_1_)')
ax.set_ylabel('log_10(pop_rad_yield_2_)')
ax.set_zlabel('clumping factor')
ax.scatter3D(ydata, zdata, tdata, marker= '.')

ax = fig.add_subplot(2, 2, 4, projection='3d')
#ax.set_title('1_3_4')
ax.set_xlabel('log_10(pop_rad_yield_0_)')
ax.set_ylabel('log_10(pop_rad_yield_2_)')
ax.set_zlabel('clumping factor')
ax.scatter3D(ydata, zdata, tdata, marker= '.')

plt.tight_layout()
plt.savefig('3d.png')
#plt.savefig('/scratch/o/oscarh/aryanah/output_1/parameters.png')
plt.show()

# %%
# %matplotlib qt 
fig1 = plt.figure()
ax = plt.axes(projection='3d')
ax.set_title('accessible regions of param space')
ax.set_xlabel('log_10(pop_rad_yield_0_)')
ax.set_ylabel('log_10(pop_rad_yield_1_)')
ax.set_zlabel('log_10(pop_rad_yield_2_)')
ax.scatter3D(xdata, ydata, zdata, marker= '.')
plt.savefig('1_2_3.png')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-0a25efadd4fd> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'qt')
#       2 fig1 = plt.figure()
#       3 ax = plt.axes(projection='3d')
#       4 ax.set_title('accessible regions of param space')
#       5 ax.set_xlabel('log_10(pop_rad_yield_0_)')
#
# /local/jupyter2021/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-101> in matplotlib(self, line)
#
# /local/jupyter2021/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /local/jupyter2021/lib/python3.8/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# /local/jupyter2021/lib/python3.8/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3504                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3505
# -> 3506         pt.activate_matplotlib(backend)
#    3507         pt.configure_inline_support(self, backend)
#    3508
#
# /local/jupyter2021/lib/python3.8/site-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     320     from matplotlib import pyplot as plt
#     321
# --> 322     plt.switch_backend(backend)
#     323
#     324     plt.show._needmain = False
#
# /local/jupyter2021/lib/python3.8/site-packages/matplotlib/pyplot.py in switch_backend(newbackend)
#     282         if (current_framework and required_framework
#     283                 and current_framework != required_framework):
# --> 284             raise ImportError(
#     285                 "Cannot load backend {!r} which requires the {!r} interactive "
#     286                 "framework, as {!r} is currently running".format(
#
# ImportError: Cannot load backend 'Qt5Agg' which requires the 'qt5' interactive framework, as 'headless' is currently running

# %%
# %matplotlib qt 
fig2 = plt.figure()
ax = plt.axes(projection='3d')
ax.set_title('accessible regions of param space')
ax.set_xlabel('log_10(pop_rad_yield_0_)')
ax.set_ylabel('log_10(pop_rad_yield_1_)')
ax.set_zlabel('clumping factor')
ax.scatter3D(xdata, ydata, tdata, marker= '.')
plt.savefig('1_2_4.png')

# %%
# %matplotlib qt 
fig3 = plt.figure()
ax = plt.axes(projection='3d')
ax.set_title('accessible regions of param space')
ax.set_xlabel('log_10(pop_rad_yield_1_)')
ax.set_ylabel('log_10(pop_rad_yield_2_)')
ax.set_zlabel('clumping factor')
ax.scatter3D(ydata, zdata, tdata, marker= '.')
plt.savefig('2_3_4.png')

# %%
# %matplotlib qt 
fig4 = plt.figure()
ax = plt.axes(projection='3d')
ax.set_title('accessible regions of param space')
ax.set_xlabel('log_10(pop_rad_yield_0_)')
ax.set_ylabel('log_10(pop_rad_yield_2_)')
ax.set_zlabel('clumping factor')
ax.scatter3D(ydata, zdata, tdata, marker= '.')
plt.savefig('1_3_4.png')

# %%
# %matplotlib qt 
plt.scatter(xdata, ydata)
plt.title('accessible regions of param space')
plt.xlabel('log_10(pop_rad_yield_0_)')
plt.ylabel('log_10(pop_rad_yield_1_)')
plt.savefig('1_2.png')

# %%
# %matplotlib qt 
plt.scatter(xdata, zdata)
plt.title('accessible regions of param space')
plt.xlabel('log_10(pop_rad_yield_0_)')
plt.ylabel('log_10(pop_rad_yield_2_)')
plt.savefig('1_3.png')

# %%
# %matplotlib qt 
plt.scatter(xdata, tdata)
plt.title('accessible regions of param space')
plt.xlabel('log_10(pop_rad_yield_0_)')
plt.ylabel('clumping factor')
plt.savefig('1_4.png')

# %%
# %matplotlib qt 
plt.scatter(ydata, zdata)
plt.title('accessible regions of param space')
plt.xlabel('log_10(pop_rad_yield_1_)')
plt.ylabel('log_10(pop_rad_yield_2_)')
plt.savefig('2_3.png')

# %%
# %matplotlib qt 
plt.scatter(ydata, tdata)
plt.title('accessible regions of param space')
plt.xlabel('log_10(pop_rad_yield_1_)')
plt.ylabel('clumping factor')
plt.savefig('2_4.png')

# %%
# %matplotlib qt 
plt.scatter(zdata, tdata)
plt.title('accessible regions of param space')
plt.xlabel('log_10(pop_rad_yield_2_)')
plt.ylabel('clumping factor')
plt.savefig('3_4.png')
